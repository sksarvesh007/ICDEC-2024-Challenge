# %%
print("hello")
# Out:
# hello

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 681.1 kB/s eta 0:00:000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.5/792.5 kB 6.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
ROOT_CONFIG_DIR = '/kaggle/input/config-file/'

# %%
import os

from ultralytics import YOLO

model = YOLO("yolov8n.yaml")  
print("done")
# Out:
# done

# %%
import os
from ultralytics import YOLO

# Define paths
DATA_CONFIG = "/kaggle/input/config-file/kaggle_config.yaml"
MODEL_CONFIG = "yolov8n.yaml" # Save in current working directory for easy download

# Train the model for 400 epochs
model = YOLO(MODEL_CONFIG)
results = model.train(data=DATA_CONFIG, epochs=400)
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
DATA_CONFIG = "/kaggle/input/config-file/kaggle_config.yaml"
CHECKPOINT_PATH = "/kaggle/input/100-epoch/last.pt"  # Path to the checkpoint

model = YOLO(CHECKPOINT_PATH)

# Continue training for the next 300 epochs
results = model.train(data=DATA_CONFIG, epochs=100, resume=True)
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
DATA_CONFIG = "/kaggle/input/config-file/kaggle_config.yaml"
CHECKPOINT_PATH = "/kaggle/input/200-epochs/last.pt"  # Path to the checkpoint

model = YOLO(CHECKPOINT_PATH)

# Continue training for the next 300 epochs
results = model.train(data=DATA_CONFIG, epochs=100, resume=True)
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
DATA_CONFIG = "/kaggle/input/config-file/kaggle_config.yaml"
CHECKPOINT_PATH = "/kaggle/input/300-epochs/last.pt"  # Path to the checkpoint

model = YOLO(CHECKPOINT_PATH)

# Continue training for the next 300 epochs
results = model.train(data=DATA_CONFIG, epochs=100, resume=True)
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print("ok")

# %%
DATA_CONFIG = "/kaggle/input/config-file/kaggle_config.yaml"  # Path to your data configuration file
CHECKPOINT_PATH = "/kaggle/working/runs/detect/train5/weights/last.pt"  # Path to your trained model checkpoint

# Load the trained model
model = YOLO(CHECKPOINT_PATH)

# Run validation
results = model.val(data=DATA_CONFIG)

# Print evaluation metrics
print("Evaluation Metrics:")
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/yolo-obj/labels/val... 196 images, 0 backgrounds, 0 corrupt: 100%|██████████| 196/196 [00:00<00:00, 742.94it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/yolo-obj/labels is not writeable, cache not saved.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:08<00:00,  1.47it/s]
#                    all        196       1262       0.82      0.733      0.787      0.389
#                    car        154        734      0.844      0.735        0.8      0.392
# ...
